# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('log.csv')
df.head()
# Out:
#    Depth     RxoRt    RLL3       SP      RILD      MN      MI    MCAL    DCAL  \
# 0  195.0  226.0848  0.4076  69.8953  132.5052 -0.3548  0.1863  5.1090  1.8878
# 1  195.5  223.5031  0.4063  69.2303  123.6225 -0.3619  0.1867  5.1031  1.8882
# 2  196.0  221.4560  0.4047  68.4478  116.9258 -0.3668  0.1860  5.0872  1.8878
# 3  196.5  219.8248  0.4033  67.4843  111.7925 -0.3613  0.1867  5.0881  1.8884
# 4  197.0  218.1438  0.4023  66.3013  106.7821 -0.3569  0.1870  5.0972  1.8883
#
#      RHOB    RHOC     DPOR     CNLS       GR
# 0  1.6973 -0.6303  59.2216  30.0657  60.4576
# 1  1.6791 -0.6409  60.2877  26.7625  54.1495
# 2  1.6585 -0.6539  61.4914  27.6017  51.9944
# 3  1.6435 -0.6649  62.3711  31.5870  52.9645
# 4  1.6390 -0.6705  62.6343  35.8251  54.9659

# %%
df.shape
# Out:
# (8739, 14)

# %%
df.plot(subplots=True, figsize=(15, 15))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig = plt.subplots(figsize=(15,10))

#Set up the plot axes
ax1 = plt.subplot2grid((1,3), (0,0), rowspan=1, colspan = 1) 
ax2 = plt.subplot2grid((1,3), (0,1), rowspan=1, colspan = 1)
ax3 = plt.subplot2grid((1,3), (0,2), rowspan=1, colspan = 1)

ax1.plot("GR", "Depth", data = df, color = "green") # Call the data from the well dataframe
ax1.set_xlabel("Gamma") # Assign a track title
ax1.set_xlim(0, 200) # Change the limits for the curve being plotted
ax1.set_ylim(4700, 3500) # Set the depth range
ax1.set_title("GR vs Depth")
ax1.grid() # Display the grid

ax2.plot("RLL3", "Depth", data = df, color = "red")
ax2.set_xlabel("Deep Res.")
ax2.set_xlim(0.2, 2000)
ax2.semilogx()
ax2.set_ylim(4700, 3500)
ax2.set_title("Deep Res. vs Depth")
ax2.grid()

ax3.plot("DPOR", "Depth", data = df, color = "blue")
ax3.set_xlabel("Density porosity")
ax3.set_xlim(1.95, 2.95)
ax3.set_ylim(4700, 3500)
ax3.set_title("Density porosity  vs Depth")
ax3.grid()
